# %% [markdown]
# In a solar panel efficiency study, researchers want to investigate the relationship between the temperature and the efficiency of solar panels. They collected data on the temperature (in Celsius) and the corresponding efficiency (in percentage) of solar panels over a period of time. The dataset contains measurements from 50 different days.
#
# a.
# Using Simple Linear Regression, can you develop a model to predict the efficiency of solar panels based on the temperature?
#
# b.
# Perform an F-test to determine whether temperature significantly predicts the efficiency of solar panels.
#
# c.
# Conduct a t-test to assess the significance of the regression coefficient for temperature.

# %% [markdown]
# The below packages are to be imported for calling their respective functions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# Data is taken from the dataset in the drive. The Housing loan dataset was added to the drive. It has only two attribtes. The independent varioable is area and the dependent variable is price of the house.

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/Housing_loan - Sheet1.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# Scatter plot for the Houseing loan data, with X axis for the independent variable and Y axix for the dependent variable.

# %%
plt.scatter(df.area, df.price, color = 'red')
plt.title('Area vs Price')
plt.xlabel('AREA')
plt.ylabel('PRICE')
plt.grid(True)
plt.show()

# %% [markdown]
# Creating a regression model.

# %% [markdown]
# 1. Creates an instance of the LinearRegression class from scikit-learn's linear_model module and assigns it to the variable reg. This object (reg) can then be used to fit a linear regression model to your dataset.
#
# 2. Fit the Model to Your Data:

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3600]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([669452.05479452])

# %% [markdown]
# y = m*x + b
#
# Coefficient is also denoted as m
# Intercept is b

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# Q-2 Starts from here.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/DV LAB/Solar panel.csv')
df
# Out:
#     Unnamed: 0  Temperature  Efficiency  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0            0    27.440675   65.188987         NaN         NaN         NaN
# 1            1    35.759468   87.633611         NaN         NaN         NaN
# 2            2    30.138169   72.520823         NaN         NaN         NaN
# 3            3    27.244159   71.431708         NaN         NaN         NaN
# 4            4    21.182740   64.327393         NaN         NaN         NaN
# 5            5    32.294706   80.034805         NaN         NaN         NaN
# 6            6    21.879361   62.870191         NaN         NaN         NaN
# 7            7    44.588650   81.230624         NaN         NaN         NaN
# 8            8    48.183138   79.614236         NaN         NaN         NaN
# 9            9    19.172076   71.520550         NaN         NaN         NaN
# 10          10    39.586252   77.239100         NaN         NaN         NaN
# ...

# %%
df.iloc[:, [1, 2]]
# Out:
#     Temperature  Efficiency
# 0     27.440675   65.188987
# 1     35.759468   87.633611
# 2     30.138169   72.520823
# 3     27.244159   71.431708
# 4     21.182740   64.327393
# 5     32.294706   80.034805
# 6     21.879361   62.870191
# 7     44.588650   81.230624
# 8     48.183138   79.614236
# 9     19.172076   71.520550
# 10    39.586252   77.239100
# 11    26.444746   67.319212
# 12    28.402228   74.060203
# 13    46.279832   85.281575
# 14     3.551803   62.108488
# 15     4.356465   63.690592
# 16     1.010920   57.333849
# 17    41.630992   79.001790
# 18    38.907838   76.091617
# 19    43.500607   79.952538
# 20    48.930917   80.399727
# 21    39.957928   71.347551
# 22    23.073968   72.424115
# 23    39.026459   77.504325
# 24     5.913721   54.805869
# 25    31.996051   78.311937
# 26     7.167664   59.047340
# 27    47.233446   83.876450
# 28    26.092416   76.691661
# 29    20.733097   71.011463
# 30    13.227781   72.310894
# 31    38.711684   73.181713
# ...

# %%
# Splitting data into Training and Testing.
X = df[['Temperature']]
y = df['Efficiency']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model = model.fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.xlabel('Temperature')
plt.ylabel('Efficiency')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_test, model.predict(X_test), color = 'blue')
plt.xlabel('Temperature')
plt.ylabel('Efficiency')
plt.title('Test Data')
plt.show()
